# %%
import pandas as pd

# %%
data = pd.read_csv("Data/wdbcdata.csv")

# %%
data.head()
# Out:
#      842302  M  17.99  10.38   122.8    1001   0.1184   0.2776  0.3001  \
# 0    842517  M  20.57  17.77  132.90  1326.0  0.08474  0.07864  0.0869
# 1  84300903  M  19.69  21.25  130.00  1203.0  0.10960  0.15990  0.1974
# 2  84348301  M  11.42  20.38   77.58   386.1  0.14250  0.28390  0.2414
# 3  84358402  M  20.29  14.34  135.10  1297.0  0.10030  0.13280  0.1980
# 4    843786  M  12.45  15.70   82.57   477.1  0.12780  0.17000  0.1578
#
#     0.1471   ...     25.38  17.33   184.6    2019  0.1622  0.6656  0.7119  \
# 0  0.07017   ...     24.99  23.41  158.80  1956.0  0.1238  0.1866  0.2416
# 1  0.12790   ...     23.57  25.53  152.50  1709.0  0.1444  0.4245  0.4504
# 2  0.10520   ...     14.91  26.50   98.87   567.7  0.2098  0.8663  0.6869
# 3  0.10430   ...     22.54  16.67  152.20  1575.0  0.1374  0.2050  0.4000
# 4  0.08089   ...     15.47  23.75  103.40   741.6  0.1791  0.5249  0.5355
#
#    0.2654  0.4601   0.1189
# 0  0.1860  0.2750  0.08902
# 1  0.2430  0.3613  0.08758
# 2  0.2575  0.6638  0.17300
# 3  0.1625  0.2364  0.07678
# 4  0.1741  0.3985  0.12440
#
# [5 rows x 32 columns]

# %%
data.shape
# Out:
# (568, 32)

# %%
data.columns = ["ID number", "Diagnosis", "Radius mean", "Texture mean", "Perimeter mean", "Area mean",
               "Smoothness mean", "Compactness mean", "Concavity mean", "Concave Points mean", "Symmetry mean", 
               "Fractal Dimension mean","Radius SE", "Texture SE", "Perimeter SE", "Area SE",
               "Smoothness SE", "Compactness SE", "Concavity SE", "Concave Points SE", "Symmetry SE", 
               "Fractal Dimension SE", "Radius worst", "Texture worst", "Perimeter worst", "Area worst",
               "Smoothness worst", "Compactness worst", "Concavity worst", "Concave Points worst", "Symmetry worst", 
               "Fractal Dimension worst"]

# %%
data.head()
# Out:
#    ID number Diagnosis  Radius mean  Texture mean  Perimeter mean  Area mean  \
# 0     842517         M        20.57         17.77          132.90     1326.0
# 1   84300903         M        19.69         21.25          130.00     1203.0
# 2   84348301         M        11.42         20.38           77.58      386.1
# 3   84358402         M        20.29         14.34          135.10     1297.0
# 4     843786         M        12.45         15.70           82.57      477.1
#
#    Smoothness mean  Compactness mean  Concavity mean  Concave Points mean  \
# 0          0.08474           0.07864          0.0869              0.07017
# 1          0.10960           0.15990          0.1974              0.12790
# 2          0.14250           0.28390          0.2414              0.10520
# 3          0.10030           0.13280          0.1980              0.10430
# 4          0.12780           0.17000          0.1578              0.08089
#
#             ...             Radius worst  Texture worst  Perimeter worst  \
# 0           ...                    24.99          23.41           158.80
# 1           ...                    23.57          25.53           152.50
# 2           ...                    14.91          26.50            98.87
# 3           ...                    22.54          16.67           152.20
# 4           ...                    15.47          23.75           103.40
#
#    Area worst  Smoothness worst  Compactness worst  Concavity worst  \
# 0      1956.0            0.1238             0.1866           0.2416
# 1      1709.0            0.1444             0.4245           0.4504
# 2       567.7            0.2098             0.8663           0.6869
# 3      1575.0            0.1374             0.2050           0.4000
# 4       741.6            0.1791             0.5249           0.5355
#
#    Concave Points worst  Symmetry worst  Fractal Dimension worst
# 0                0.1860          0.2750                  0.08902
# 1                0.2430          0.3613                  0.08758
# 2                0.2575          0.6638                  0.17300
# 3                0.1625          0.2364                  0.07678
# 4                0.1741          0.3985                  0.12440
#
# [5 rows x 32 columns]

# %%
data.to_csv('wdbcDataComplete.csv')

# %%
data2 = pd.read_csv("Data/wpbcdata.csv")
data2.head()
# Out:
#    119513  N   31  18.02   27.6   117.5    1013  0.09489  0.1036  0.1086 ...   \
# 0    8423  N   61  17.99  10.38  122.80  1001.0  0.11840  0.2776  0.3001 ...
# 1  842517  N  116  21.37  17.44  137.50  1373.0  0.08836  0.1189  0.1255 ...
# 2  843483  N  123  11.42  20.38   77.58   386.1  0.14250  0.2839  0.2414 ...
# 3  843584  R   27  20.29  14.34  135.10  1297.0  0.10030  0.1328  0.1980 ...
# 4  843786  R   77  12.75  15.29   84.60   502.7  0.11890  0.1569  0.1664 ...
#
#     139.7    1436  0.1195  0.1926   0.314   0.117  0.2677  0.08113    5  5.1
# 0  184.60  2019.0  0.1622  0.6656  0.7119  0.2654  0.4601  0.11890  3.0    2
# 1  159.10  1949.0  0.1188  0.3449  0.3414  0.2032  0.4334  0.09067  2.5    0
# 2   98.87   567.7  0.2098  0.8663  0.6869  0.2575  0.6638  0.17300  2.0    0
# 3  152.20  1575.0  0.1374  0.2050  0.4000  0.1625  0.2364  0.07678  3.5    0
# 4  107.30   733.2  0.1706  0.4196  0.5999  0.1709  0.3485  0.11790  2.5    0
#
# [5 rows x 35 columns]

# %%
data2.shape
# Out:
# (197, 35)

# %%
data2.columns = ["ID number", "Outcome", "Time", "Radius mean", "Texture mean", "Perimeter mean", "Area mean",
               "Smoothness mean", "Compactness mean", "Concavity mean", "Concave Points mean", "Symmetry mean", 
               "Fractal Dimension mean","Radius SE", "Texture SE", "Perimeter SE", "Area SE",
               "Smoothness SE", "Compactness SE", "Concavity SE", "Concave Points SE", "Symmetry SE", 
               "Fractal Dimension SE", "Radius worst", "Texture worst", "Perimeter worst", "Area worst",
               "Smoothness worst", "Compactness worst", "Concavity worst", "Concave Points worst", "Symmetry worst", 
               "Fractal Dimension worst", "Tumor size", "Lymph node status"]

# %%
data2.head()
# Out:
#    ID number Outcome  Time  Radius mean  Texture mean  Perimeter mean  \
# 0       8423       N    61        17.99         10.38          122.80
# 1     842517       N   116        21.37         17.44          137.50
# 2     843483       N   123        11.42         20.38           77.58
# 3     843584       R    27        20.29         14.34          135.10
# 4     843786       R    77        12.75         15.29           84.60
#
#    Area mean  Smoothness mean  Compactness mean  Concavity mean  \
# 0     1001.0          0.11840            0.2776          0.3001
# 1     1373.0          0.08836            0.1189          0.1255
# 2      386.1          0.14250            0.2839          0.2414
# 3     1297.0          0.10030            0.1328          0.1980
# 4      502.7          0.11890            0.1569          0.1664
#
#          ...          Perimeter worst  Area worst  Smoothness worst  \
# 0        ...                   184.60      2019.0            0.1622
# 1        ...                   159.10      1949.0            0.1188
# 2        ...                    98.87       567.7            0.2098
# 3        ...                   152.20      1575.0            0.1374
# 4        ...                   107.30       733.2            0.1706
#
#    Compactness worst  Concavity worst  Concave Points worst  Symmetry worst  \
# 0             0.6656           0.7119                0.2654          0.4601
# 1             0.3449           0.3414                0.2032          0.4334
# 2             0.8663           0.6869                0.2575          0.6638
# 3             0.2050           0.4000                0.1625          0.2364
# 4             0.4196           0.5999                0.1709          0.3485
#
#    Fractal Dimension worst  Tumor size  Lymph node status
# 0                  0.11890         3.0                  2
# 1                  0.09067         2.5                  0
# 2                  0.17300         2.0                  0
# 3                  0.07678         3.5                  0
# 4                  0.11790         2.5                  0
#
# [5 rows x 35 columns]

# %%
data2.to_csv('wpbcDataComplete.csv')

# %%
FinalData=data.merge(data2)

# %%
FinalData.shape
# Out:
# (126, 36)

# %%
FinalData.head()
# Out:
#    ID number Diagnosis  Radius mean  Texture mean  Perimeter mean  Area mean  \
# 0     844981         M        13.00         21.82           87.50      519.8
# 1     845636         M        16.02         23.24          102.70      797.8
# 2     846381         M        15.85         23.95          103.70      782.7
# 3     848406         M        14.68         20.13           94.74      684.5
# 4    8511133         M        15.34         14.26          102.50      704.4
#
#    Smoothness mean  Compactness mean  Concavity mean  Concave Points mean  \
# 0          0.12730           0.19320         0.18590              0.09353
# 1          0.08206           0.06669         0.03299              0.03323
# 2          0.08401           0.10020         0.09938              0.05364
# 3          0.09867           0.07200         0.07395              0.05259
# 4          0.10730           0.21350         0.20770              0.09756
#
#          ...          Smoothness worst  Compactness worst  Concavity worst  \
# 0        ...                    0.1703             0.5401           0.5390
# 1        ...                    0.1181             0.1551           0.1459
# 2        ...                    0.1131             0.1924           0.2322
# 3        ...                    0.1464             0.1871           0.2914
# 4        ...                    0.1390             0.5954           0.6305
#
#    Concave Points worst  Symmetry worst  Fractal Dimension worst  Outcome  \
# 0               0.20600          0.4378                  0.10720        N
# 1               0.09975          0.2948                  0.08452        N
# 2               0.11190          0.2809                  0.06287        N
# 3               0.16090          0.3029                  0.08216        N
# 4               0.23930          0.4667                  0.09946        N
#
#    Time  Tumor size  Lymph node status
# 0   119         2.0                  1
# 1   123         2.0                  0
# 2   117         1.0                  0
# 3   123         1.1                  0
# 4    20         1.3                  0
#
# [5 rows x 36 columns]

# %%
FinalData
