# %%
import matplotlib.pyplot as plt
from sklearn.neighbors import KNeighborsClassifier
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('Data/FinalDataset.csv')
del data["Outcome"]

# %%
# pd.get_dummies(data.Diagnosis)
target = data["Diagnosis"]
target_names = ["negative", "positive"]

# %%
data_new = data.drop("Diagnosis", axis=1)
feature_names = data_new.columns
data_new
# Out:
#      Unnamed: 0  ID number  Radius mean_x  Texture mean_x  Perimeter mean_x  \
# 0             0     842517         20.570           17.77            132.90
# 1             1   84300903         19.690           21.25            130.00
# 2             2   84348301         11.420           20.38             77.58
# 3             3   84358402         20.290           14.34            135.10
# 4             4     843786         12.450           15.70             82.57
# 5             5     844359         18.250           19.98            119.60
# 6             6   84458202         13.710           20.83             90.20
# 7             7     844981         13.000           21.82             87.50
# 8             8   84501001         12.460           24.04             83.97
# 9             9     845636         16.020           23.24            102.70
# 10           10   84610002         15.780           17.89            103.60
# ...

# %%
data_new.replace('?', np.nan)
# Out:
#      Unnamed: 0  ID number  Radius mean_x  Texture mean_x  Perimeter mean_x  \
# 0             0     842517         20.570           17.77            132.90
# 1             1   84300903         19.690           21.25            130.00
# 2             2   84348301         11.420           20.38             77.58
# 3             3   84358402         20.290           14.34            135.10
# 4             4     843786         12.450           15.70             82.57
# 5             5     844359         18.250           19.98            119.60
# 6             6   84458202         13.710           20.83             90.20
# 7             7     844981         13.000           21.82             87.50
# 8             8   84501001         12.460           24.04             83.97
# 9             9     845636         16.020           23.24            102.70
# 10           10   84610002         15.780           17.89            103.60
# ...

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(data_new, target, random_state=42)

# %%
# Support vector machine linear classifier
from sklearn.svm import SVC 
model = SVC(kernel='linear')
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-bfb639500702> in <module>()
#       2 from sklearn.svm import SVC
#       3 model = SVC(kernel='linear')
# ----> 4 model.fit(X_train, y_train)
#
# /anaconda3/lib/python3.6/site-packages/sklearn/svm/base.py in fit(self, X, y, sample_weight)
#     147         self._sparse = sparse and not callable(self.kernel)
#     148
# --> 149         X, y = check_X_y(X, y, dtype=np.float64, order='C', accept_sparse='csr')
#     150         y = self._validate_targets(y)
#     151
#
# /anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py in check_X_y(X, y, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, multi_output, ensure_min_samples, ensure_min_features, y_numeric, warn_on_dtype, estimator)
#     571     X = check_array(X, accept_sparse, dtype, order, copy, force_all_finite,
# ...
